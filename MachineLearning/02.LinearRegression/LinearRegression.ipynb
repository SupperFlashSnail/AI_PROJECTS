# %% [markdown]
# ## LinearRegression概述
#
# 线性回归是利用回归分析方式来确定多种变量之间的依赖关系：
# y = WX+e 其中W为ShapeSize=[1，N]的权重参数 e为预测误差 y为实际值
#
# ## 线性回归原理图
# 线性回归实际上是求出一个N维的超平面，使所有样本数据都在其上下一定范围内浮动。
# <img src="LinearRegression.png" >
#
# ## 线性回归的要求
# ```
# 1. 自变量和因变量之间存在线性关系，可以通过绘制散点图矩阵进行考察
# 2. 自变量和自变量之间相互独立，即自变量之间协方差为0
# 3. 误差服从期望为0独立的正态分布
# 4. 误差大小不会随着变量的变化而变化，即方差齐性
# ```
# ```
# 基本条件的原因分析：
# y =[θ0，,θ1，θ2，θ3....][X1,X2,X3....] + e 其中特征向量X为因变量，W变量权重，e为预测误差，为固定值，其中e为所有样本预测误差的均值，为一个固定值。自变量和隐变量应该线性相关，否则通过线性表达式则无法诠释样本的分布；自变量和自变量之间相互独立，否则不能进行线性相加；误差服从期望为0独立的正态分布，否则无法满足最大似然估计的条件；误差大小满足齐性，即e是一个固定值，否则不能满足线性方程求解。
# ```
#
# ## 最大似然估计值
# ```
# 最大似然估计值是求出所有样本预测值和真实值之间的误差之和最小，其表示方法为所有样本预测误差通过正态分布N-(0,u)概率密度的计算后得到概率，然后所有概率的乘积即可得到似然估计值，当所有样本的预测误差都趋近于0，则似然估计值最大，似然估计最大，则表示权重值越正确。
# ```
# <img src='./maximum.jpg' style='zoom:60%'>
#
# ```
# 最大似然估计为目标求解函数，在学习的过程中通过梯度下降方式，使目标函数值最大，通过梯度求导，求得每一步的梯度变化方向，然后乘以学习率，最终求出梯度更新尺度。
#
# 其中梯度数学表达式的物理含义是：所有误差值和对应特征元乘积的期望值
# ```
# <img src='./grad.png' style='zoom:60%'>
#
# ```
# 值得注意的是，为了防止过拟合，即使最后学习的W权重能够有更大泛化能力，会在权重更新时加上正则化惩罚项
# ```

# %% [markdown]
# ###  数据处理

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
features_labels = ['accommodates','bedrooms','bathrooms','beds','price','minimum_nights','maximum_nights','number_of_reviews']
features=['accommodates','bedrooms','bathrooms','beds','minimum_nights','maximum_nights','number_of_reviews']

dc_listings = pd.read_csv('listings.csv')

dc_listings = dc_listings[features_labels]

dc_listings['price'] = dc_listings.price.str.replace("\$|,",'').astype(float) #字符串转换

dc_listings = dc_listings[dc_listings.price < 500][dc_listings.price > 100]

max_price = dc_listings.price.max()

min_price = dc_listings.price.min()

dc_listings['price'] = (dc_listings['price']-min_price)/(max_price - min_price) #对价格进行归一化处理

dc_listings = dc_listings.dropna()    #去掉空值


dc_listings[features] = StandardScaler().fit_transform(dc_listings[features]) #数据标准化处理

dc_listings['pad_one'] = 1

features.append('pad_one')

normalized_listings = dc_listings   #将指定特征数据取出

norm_train_df = normalized_listings.copy().iloc[0:2792]
norm_test_df = normalized_listings.copy().iloc[2792:]
# Out:
# C:\Users\PC\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if sys.path[0] == '':

# %%
norm_train_data = norm_train_df[features]
norm_train_label = norm_train_df['price']
norm_test_data = norm_test_df[features]
norm_test_label = norm_test_df['price']

# %%
norm_train_data.head(5)
# Out:
#     accommodates  bedrooms  bathrooms      beds  minimum_nights  \
# 0       0.106575 -0.414744  -0.536678  0.107118       -0.308069
# 1       1.101111  1.803475   2.841286  0.975726       -0.083765
# 17     -0.887961 -0.414744  -0.536678  0.107118       -0.308069
# 19     -0.887961 -0.414744  -0.536678 -0.761489       -0.308069
# 21     -0.887961 -0.414744  -0.536678 -0.761489       -0.308069
#
#     maximum_nights  number_of_reviews  pad_one
# 0        -0.022402          -0.541295        1
# 1        -0.022425           1.835919        1
# 17       -0.022402          -0.541295        1
# 19       -0.022402          -0.541295        1
# 21       -0.022402          -0.541295        1

# %% [markdown]
# ## 1. 通过自己代码实现线性回归预测

# %%
norm_train_data.values
# Out:
# array([[ 1.06575111e-01, -4.14744088e-01, -5.36677939e-01, ...,
#         -2.24023659e-02, -5.41295306e-01,  1.00000000e+00],
#        [ 1.10111130e+00,  1.80347496e+00,  2.84128555e+00, ...,
#         -2.24252374e-02,  1.83591931e+00,  1.00000000e+00],
#        [-8.87961075e-01, -4.14744088e-01, -5.36677939e-01, ...,
#         -2.24023659e-02, -5.41295306e-01,  1.00000000e+00],
#        ...,
#        [ 1.10111130e+00,  6.94365435e-01, -5.36677939e-01, ...,
#          4.48325375e+01, -1.02424915e-01,  1.00000000e+00],
#        [-8.87961075e-01, -4.14744088e-01, -5.36677939e-01, ...,
#         -2.24254254e-02,  1.21418626e+00,  1.00000000e+00],
#        [-3.90692982e-01, -1.52385361e+00, -5.36677939e-01, ...,
#         -2.24023659e-02, -5.04722773e-01,  1.00000000e+00]])

# %%
import numpy as np

# %%
def loss_fun(predicts,labels):
    loss = labels.flatten() -  predicts.flatten() 
    return loss

# %%
def grad_get(predicts,labels,train_data,theta,lr):
    
    loss = loss_fun(predicts,labels.values)
    grad = np.zeros(len(theta))
    for i in range(0,len(theta)):
        grad_tmp = 0
        for j in range(0,len(train_data)):
            grad_tmp = grad_tmp + train_data.values[j][i]*loss[i]
        grad[i] = lr*grad_tmp/(len(train_data))
    
    return grad

# %%
def weight_update(theta,grad):
    theta = theta - grad.reshape(8,1)
    return theta

# %%
steps = 100
theta = np.ones((8,1))   #定义权重参数
lr = 0.001                #定义学习率
for step in range(steps):
    predicts =  np.dot(norm_train_data.values,theta)
    grad = grad_get(predicts,norm_train_label,norm_train_data,theta,lr)
    theta = weight_update(theta,grad)
    
    if step % 10 == 0:
        print(loss_fun(predicts,norm_train_label.values).sum()/len(norm_train_data))
# Out:
# -0.8070436718650437
# -0.8327970458352778
# -0.8588091155428623
# -0.8850824796175768
# -0.9116197627927495
# -0.9384236161674704
# -0.9654967174714386
# -0.9928417713324695
# -1.0204615095466902
# -1.0483586913514484

# %% [markdown]
# ## 2. 使用SKLEARN库实现线性回归

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

boston = datasets.load_boston()
x, y = boston.data, boston.target
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=10010)
reg = LinearRegression()
reg.fit(x_train, y_train)
y_predict = reg.predict(x_test)
print(mean_squared_error(y_test, y_predict))
# Out:
# 15.78937682781807

# %%
print(x_train.shape)
print(y_train.shape)
print(x_train)
y_train
# Out:
# (379, 13)
# (379,)
# [[4.62960e-01 0.00000e+00 6.20000e+00 ... 1.74000e+01 3.76140e+02
#   5.25000e+00]
#  [1.44760e-01 0.00000e+00 1.00100e+01 ... 1.78000e+01 3.91500e+02
#   1.36100e+01]
#  [1.12658e+00 0.00000e+00 1.95800e+01 ... 1.47000e+01 3.43280e+02
#   1.21200e+01]
#  ...
#  [9.76170e-01 0.00000e+00 2.18900e+01 ... 2.12000e+01 2.62760e+02
#   1.73100e+01]
#  [9.55770e-01 0.00000e+00 8.14000e+00 ... 2.10000e+01 3.06380e+02
#   1.72800e+01]
#  [3.67822e+00 0.00000e+00 1.81000e+01 ... 2.02000e+01 3.80790e+02
#   1.01900e+01]]
# array([31.7, 19.3, 15.3, 23.7, 22. , 23.9, 23.8, 38.7, 10.2, 21. , 18.2,
#        19.8, 13. , 11.8, 23.9, 20. , 19.1, 24.7, 34.9, 37.3, 18.7, 19.2,
#        26.6, 15.6,  8.5, 17.7,  5. , 20.9, 16.7, 17.5, 20.7, 50. ,  8.4,
#        23.9, 25. , 33.2, 20.1,  8.8, 27.5, 12.1, 24.4, 21.9, 19.7, 18.1,
#        17.9, 19.8, 17. , 43.5, 19.3, 23.7, 32.2, 20.3, 13.5, 50. , 14.1,
#        23. , 26.2, 25.3, 11.3, 17.8, 20.5, 21.2, 17.8, 17.2, 25. , 18.6,
#        15.2, 36.2, 19.5, 20.6, 37.2, 23.2, 24.4, 12.6, 27.9, 21.2, 50. ,
#        19.9, 24.8, 25. , 29.9, 41.7, 23.1, 12.7, 43.1, 14.9, 22.6, 33.1,
#         9.5, 27.1, 24.1, 14.2, 29.6, 14.1, 32.5, 18.5, 29.1, 24.4, 18.5,
#        24.3, 50. , 20.6, 50. ,  7. , 19.4, 22.6, 33.1, 32. , 31. , 24.3,
#        10.2, 31.1, 17.4, 23.8, 23.9, 15.6, 20. , 34.9, 50. , 18.4, 15.2,
#        30.8, 13.4, 50. , 20.1, 22.8, 20.8, 22.6, 16.8, 21.4, 16.6, 22. ,
#        19.6, 24.8, 17.2, 15. , 22.5,  7.5, 18.5, 18.7, 21.2, 27.9, 50. ,
#        17.4, 19.6, 19.6, 23.5, 24.3, 50. , 45.4, 20.6, 14.6, 23. , 22.9,
#        28.7, 22.5, 30.1, 48.3, 23.1, 35.2, 28. , 13.4, 20.2, 20.7, 21. ,
#        20.3, 36. , 16.2, 33.4,  9.7, 34.9, 23.1, 18.4,  8.3, 22.2, 13.4,
#        11.9, 35.4, 10.9, 27.5, 24.5, 13.1, 16. , 22.9, 10.4, 50. , 48.5,
#        16.1, 33.2, 16.1, 21.7, 22.8, 19.1, 34.7,  7.2, 23.8, 21.5,  8.8,
#        21.8, 20.1, 30.1, 24.7, 21.8, 10.5, 31.5, 21.7, 13.9,  7.2, 35.4,
#         5. , 18.5, 36.1, 19.3, 33.4, 19.6, 24.2, 10.5, 19.9, 16.1, 24.7,
#        19.8, 20.5, 22.8, 37.6, 19.9, 21.4, 50. ,  9.6, 22.4, 28.7, 14.4,
#        22. , 20.4, 19.3, 32.4, 24.8, 24.6, 22.4, 16.3, 15.6, 18.8, 17.8,
#        31.6, 28.1, 13.8, 14.5, 18. , 13.8, 23.3, 24.6,  8.7, 22.3, 29.8,
#        22.6, 21.9, 19. ,  5.6, 25. , 19.3, 11.8, 13.3, 21.5, 20.1, 22. ,
#        28.4, 30.1, 19.4, 24.8, 16.4, 19.5, 36.2, 14.5, 16.7, 12. , 21.1,
#        18.4, 50. , 46. , 25. , 23.2, 20.2, 16.2, 12.3, 25. , 14.9, 50. ,
#        23.9, 17.4, 24.5, 24. , 13.6, 23.1, 10.2, 34.6, 17.6, 13.1, 28.7,
#         7. , 42.8, 19.4, 29. , 20.5, 48.8,  8.3, 19.1, 44. , 33. , 13.8,
#        20. , 15.2, 22.2, 23.4, 12.8, 13.8, 23.1, 20.6,  8.5, 13.1, 18.2,
#        22.6, 22.7, 16.5,  6.3, 20. , 16.8, 14.9, 22.5, 50. , 23.6, 29. ,
#        18.2, 36.4, 24.1, 50. , 23.4, 21.6, 30.3, 19.7, 17.1, 18.9, 22.9,
#        29.8, 11.7, 23. , 22. , 18.3, 11.5, 23.3, 30.5, 32.9, 23.2, 28.5,
#        37. , 32. , 20.4, 33.3, 27.1, 26.5, 31.5,  8.1, 20.6, 15.1, 23.8,
#        23.1, 15. , 19.4, 12.5, 17.2, 23.1, 22.2, 20.6, 31.6, 27.5, 13.9,
#        21.7, 27. , 15.6, 14.8, 20.8])

# %% [markdown]
# ## 3.使用pytorch实现线性回归模型

# %%
import torch 
import torch.optim as optim
import torch.nn as nn
import warnings

warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
class XLinearRegression(nn.Module):
    def __init__(self,InputChanels,OutPutChanels):
        super().__init__()
        self.out = nn.Linear(InputChanels,OutPutChanels)
    def forward(self,x):
        x = self.out(x)
        return x

# %%
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import numpy as np


boston = datasets.load_boston()
x, y = boston.data, boston.target
x = x.astype('float32')    #nn.Module网络层计算只用于float类型
y = y.astype('float32')    #numpy不能使用dtype转换数据类型，会知道元素个数改变
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=10010)

def  DataGet(x_train, x_test, y_train, y_test,bs):
    x_train, x_test, y_train, y_test = map(torch.tensor,(x_train, x_test, y_train, y_test))
    train_ds = TensorDataset(x_train, y_train)
    train_dl = DataLoader(train_ds, batch_size=bs, shuffle=True)
    valid_ds = TensorDataset(x_test, y_test)
    valid_dl = DataLoader(valid_ds, batch_size=bs)
    return train_dl,valid_dl

# %%
import torch.nn.functional as F

def GetModelWithOptAndLossFunc(InputChanels,OutPutChanels):
    model = XLinearRegression(InputChanels,OutPutChanels)
    opt = optim.Adam(model.parameters(),lr=0.001)
    loss_func = F.l1_loss
    return model,opt,loss_func

# %%
def loss_batch(model, loss_func, xb, yb, opt=None):
    loss = loss_func(model(xb), yb)
    if opt is not None:
        loss.backward()
        opt.step()
        opt.zero_grad()
    return loss.item(), len(xb)

# %%
def model_fit(steps, model, loss_func, opt, train_dl, valid_dl):
    for step in range(steps):
        model.train()
        for xb,yb in train_dl:
            print(xb.shape)
            loss_batch(model, loss_func, xb, yb, opt)
        
        model.eval()
        with torch.no_grad():
            losses, nums = zip(
                *[loss_batch(model, loss_func, xb, yb) for xb, yb in valid_dl])
        val_loss = np.sum(np.multiply(losses, nums)) / np.sum(nums)
        print('当前step:'+str(step), '验证集损失：'+str(val_loss))

# %%
bs = len(x_train)
steps = 1000
InputChanels = x_train.shape[1]
OutPutChanels = 1
train_dl, valid_dl = DataGet(x_train, x_test, y_train, y_test,bs)
model, opt,loss_func = GetModelWithOptAndLossFunc(InputChanels,OutPutChanels)
model_fit(steps, model, loss_func, opt, train_dl, valid_dl)
# Out:
# torch.Size([379, 13])
# 当前step:0 验证集损失：43.51631164550781
# torch.Size([379, 13])
# 当前step:1 验证集损失：42.61759948730469
# torch.Size([379, 13])
# 当前step:2 验证集损失：41.72029495239258
# torch.Size([379, 13])
# 当前step:3 验证集损失：40.82411575317383
# torch.Size([379, 13])
# 当前step:4 验证集损失：39.93000411987305
# torch.Size([379, 13])
# 当前step:5 验证集损失：39.037010192871094
# torch.Size([379, 13])
# 当前step:6 验证集损失：38.14741516113281
# torch.Size([379, 13])
# 当前step:7 验证集损失：37.25994873046875
# torch.Size([379, 13])
# 当前step:8 验证集损失：36.375125885009766
# torch.Size([379, 13])
# 当前step:9 验证集损失：35.49386978149414
# torch.Size([379, 13])
# 当前step:10 验证集损失：34.61571502685547
# torch.Size([379, 13])
# 当前step:11 验证集损失：33.741092681884766
# torch.Size([379, 13])
# 当前step:12 验证集损失：32.87074279785156
# torch.Size([379, 13])
# 当前step:13 验证集损失：32.00518798828125
# torch.Size([379, 13])
# 当前step:14 验证集损失：31.145238876342773
# torch.Size([379, 13])
# 当前step:15 验证集损失：30.29132080078125
# torch.Size([379, 13])
# 当前step:16 验证集损失：29.443405151367188
# torch.Size([379, 13])
# 当前step:17 验证集损失：28.602767944335938
# torch.Size([379, 13])
# 当前step:18 验证集损失：27.76896095275879
# torch.Size([379, 13])
# 当前step:19 验证集损失：26.942306518554688
# torch.Size([379, 13])
# 当前step:20 验证集损失：26.124305725097656
# torch.Size([379, 13])
# 当前step:21 验证集损失：25.315561294555664
# torch.Size([379, 13])
# 当前step:22 验证集损失：24.51582145690918
# torch.Size([379, 13])
# 当前step:23 验证集损失：23.727853775024414
# torch.Size([379, 13])
# 当前step:24 验证集损失：22.952070236206055
# torch.Size([379, 13])
# 当前step:25 验证集损失：22.189407348632812
# torch.Size([379, 13])
# 当前step:26 验证集损失：21.441295623779297
# torch.Size([379, 13])
# 当前step:27 验证集损失：20.70754051208496
# torch.Size([379, 13])
# 当前step:28 验证集损失：19.98936653137207
# torch.Size([379, 13])
# 当前step:29 验证集损失：19.287353515625
# torch.Size([379, 13])
# 当前step:30 验证集损失：18.601964950561523
# torch.Size([379, 13])
# 当前step:31 验证集损失：17.93518829345703
# torch.Size([379, 13])
# 当前step:32 验证集损失：17.289152145385742
# torch.Size([379, 13])
# 当前step:33 验证集损失：16.66444206237793
# torch.Size([379, 13])
# 当前step:34 验证集损失：16.06223487854004
# torch.Size([379, 13])
# 当前step:35 验证集损失：15.486176490783691
# torch.Size([379, 13])
# 当前step:36 验证集损失：14.93559741973877
# torch.Size([379, 13])
# 当前step:37 验证集损失：14.409799575805664
# torch.Size([379, 13])
# 当前step:38 验证集损失：13.90979290008545
# torch.Size([379, 13])
# 当前step:39 验证集损失：13.438217163085938
# torch.Size([379, 13])
# 当前step:40 验证集损失：12.993837356567383
# torch.Size([379, 13])
# 当前step:41 验证集损失：12.576369285583496
# torch.Size([379, 13])
# 当前step:42 验证集损失：12.187823295593262
# torch.Size([379, 13])
# 当前step:43 验证集损失：11.827052116394043
# torch.Size([379, 13])
# 当前step:44 验证集损失：11.494529724121094
# torch.Size([379, 13])
# 当前step:45 验证集损失：11.190909385681152
# torch.Size([379, 13])
# 当前step:46 验证集损失：10.9143705368042
# torch.Size([379, 13])
# 当前step:47 验证集损失：10.664990425109863
# torch.Size([379, 13])
# 当前step:48 验证集损失：10.442325592041016
# torch.Size([379, 13])
# 当前step:49 验证集损失：10.24527645111084
# torch.Size([379, 13])
# 当前step:50 验证集损失：10.072033882141113
# torch.Size([379, 13])
# 当前step:51 验证集损失：9.919654846191406
# torch.Size([379, 13])
# 当前step:52 验证集损失：9.785640716552734
# torch.Size([379, 13])
# 当前step:53 验证集损失：9.669303894042969
# torch.Size([379, 13])
# 当前step:54 验证集损失：9.569552421569824
# torch.Size([379, 13])
# 当前step:55 验证集损失：9.483698844909668
# torch.Size([379, 13])
# 当前step:56 验证集损失：9.408183097839355
# torch.Size([379, 13])
# 当前step:57 验证集损失：9.342202186584473
# torch.Size([379, 13])
# 当前step:58 验证集损失：9.284518241882324
# torch.Size([379, 13])
# 当前step:59 验证集损失：9.232706069946289
# torch.Size([379, 13])
# 当前step:60 验证集损失：9.185890197753906
# torch.Size([379, 13])
# 当前step:61 验证集损失：9.142520904541016
# torch.Size([379, 13])
# 当前step:62 验证集损失：9.10273265838623
# torch.Size([379, 13])
# 当前step:63 验证集损失：9.065147399902344
# torch.Size([379, 13])
# 当前step:64 验证集损失：9.029051780700684
# torch.Size([379, 13])
# 当前step:65 验证集损失：8.99409008026123
# torch.Size([379, 13])
# 当前step:66 验证集损失：8.959274291992188
# torch.Size([379, 13])
# 当前step:67 验证集损失：8.924034118652344
# torch.Size([379, 13])
# 当前step:68 验证集损失：8.88824462890625
# torch.Size([379, 13])
# 当前step:69 验证集损失：8.851571083068848
# torch.Size([379, 13])
# 当前step:70 验证集损失：8.814085006713867
# torch.Size([379, 13])
# 当前step:71 验证集损失：8.775893211364746
# torch.Size([379, 13])
# 当前step:72 验证集损失：8.737181663513184
# torch.Size([379, 13])
# 当前step:73 验证集损失：8.697837829589844
# torch.Size([379, 13])
# 当前step:74 验证集损失：8.65807819366455
# torch.Size([379, 13])
# 当前step:75 验证集损失：8.617884635925293
# torch.Size([379, 13])
# 当前step:76 验证集损失：8.577439308166504
# torch.Size([379, 13])
# 当前step:77 验证集损失：8.536897659301758
# torch.Size([379, 13])
# 当前step:78 验证集损失：8.496499061584473
# torch.Size([379, 13])
# 当前step:79 验证集损失：8.456369400024414
# torch.Size([379, 13])
# 当前step:80 验证集损失：8.416489601135254
# torch.Size([379, 13])
# 当前step:81 验证集损失：8.37734603881836
# torch.Size([379, 13])
# 当前step:82 验证集损失：8.338958740234375
# torch.Size([379, 13])
# 当前step:83 验证集损失：8.301308631896973
# torch.Size([379, 13])
# 当前step:84 验证集损失：8.264561653137207
# torch.Size([379, 13])
# 当前step:85 验证集损失：8.22866153717041
# torch.Size([379, 13])
# 当前step:86 验证集损失：8.19374942779541
# torch.Size([379, 13])
# 当前step:87 验证集损失：8.1596097946167
# torch.Size([379, 13])
# 当前step:88 验证集损失：8.126489639282227
# torch.Size([379, 13])
# 当前step:89 验证集损失：8.094027519226074
# torch.Size([379, 13])
# 当前step:90 验证集损失：8.06236457824707
# torch.Size([379, 13])
# 当前step:91 验证集损失：8.031387329101562
# torch.Size([379, 13])
# 当前step:92 验证集损失：8.001173973083496
# torch.Size([379, 13])
# 当前step:93 验证集损失：7.971364498138428
# torch.Size([379, 13])
# 当前step:94 验证集损失：7.942067623138428
# torch.Size([379, 13])
# 当前step:95 验证集损失：7.913186073303223
# torch.Size([379, 13])
# 当前step:96 验证集损失：7.8847246170043945
# torch.Size([379, 13])
# 当前step:97 验证集损失：7.856563568115234
# torch.Size([379, 13])
# 当前step:98 验证集损失：7.82858943939209
# torch.Size([379, 13])
# 当前step:99 验证集损失：7.800875663757324
# torch.Size([379, 13])
# 当前step:100 验证集损失：7.7733612060546875
# torch.Size([379, 13])
# 当前step:101 验证集损失：7.745979309082031
# torch.Size([379, 13])
# 当前step:102 验证集损失：7.718698978424072
# torch.Size([379, 13])
# 当前step:103 验证集损失：7.691547870635986
# torch.Size([379, 13])
# 当前step:104 验证集损失：7.66448974609375
# torch.Size([379, 13])
# 当前step:105 验证集损失：7.637608528137207
# torch.Size([379, 13])
# 当前step:106 验证集损失：7.6109089851379395
# torch.Size([379, 13])
# 当前step:107 验证集损失：7.584290504455566
# torch.Size([379, 13])
# 当前step:108 验证集损失：7.5579423904418945
# torch.Size([379, 13])
# 当前step:109 验证集损失：7.531872749328613
# torch.Size([379, 13])
# 当前step:110 验证集损失：7.5061187744140625
# torch.Size([379, 13])
# 当前step:111 验证集损失：7.4806294441223145
# torch.Size([379, 13])
# 当前step:112 验证集损失：7.455508708953857
# torch.Size([379, 13])
# 当前step:113 验证集损失：7.4307684898376465
# torch.Size([379, 13])
# 当前step:114 验证集损失：7.406435012817383
# torch.Size([379, 13])
# 当前step:115 验证集损失：7.382648944854736
# torch.Size([379, 13])
# 当前step:116 验证集损失：7.359421253204346
# torch.Size([379, 13])
# 当前step:117 验证集损失：7.336746692657471
# torch.Size([379, 13])
# 当前step:118 验证集损失：7.314623832702637
# torch.Size([379, 13])
# 当前step:119 验证集损失：7.293109893798828
# torch.Size([379, 13])
# 当前step:120 验证集损失：7.272039890289307
# torch.Size([379, 13])
# 当前step:121 验证集损失：7.251533031463623
# torch.Size([379, 13])
# 当前step:122 验证集损失：7.231540679931641
# torch.Size([379, 13])
# 当前step:123 验证集损失：7.211972713470459
# torch.Size([379, 13])
# 当前step:124 验证集损失：7.192975997924805
# torch.Size([379, 13])
# 当前step:125 验证集损失：7.1745195388793945
# torch.Size([379, 13])
# 当前step:126 验证集损失：7.156625270843506
# torch.Size([379, 13])
# 当前step:127 验证集损失：7.1391448974609375
# torch.Size([379, 13])
# 当前step:128 验证集损失：7.122180461883545
# torch.Size([379, 13])
# 当前step:129 验证集损失：7.105722904205322
# torch.Size([379, 13])
# 当前step:130 验证集损失：7.08970832824707
# torch.Size([379, 13])
# 当前step:131 验证集损失：7.0742011070251465
# torch.Size([379, 13])
# 当前step:132 验证集损失：7.059085845947266
# torch.Size([379, 13])
# 当前step:133 验证集损失：7.044395446777344
# torch.Size([379, 13])
# 当前step:134 验证集损失：7.03015661239624
# torch.Size([379, 13])
# 当前step:135 验证集损失：7.016333103179932
# torch.Size([379, 13])
# 当前step:136 验证集损失：7.002861499786377
# torch.Size([379, 13])
# 当前step:137 验证集损失：6.989689350128174
# torch.Size([379, 13])
# 当前step:138 验证集损失：6.976924896240234
# torch.Size([379, 13])
# 当前step:139 验证集损失：6.964559078216553
# torch.Size([379, 13])
# 当前step:140 验证集损失：6.952386379241943
# torch.Size([379, 13])
# 当前step:141 验证集损失：6.940500259399414
# torch.Size([379, 13])
# 当前step:142 验证集损失：6.928924083709717
# torch.Size([379, 13])
# 当前step:143 验证集损失：6.917616367340088
# torch.Size([379, 13])
# 当前step:144 验证集损失：6.906533718109131
# torch.Size([379, 13])
# 当前step:145 验证集损失：6.895712375640869
# torch.Size([379, 13])
# 当前step:146 验证集损失：6.88505220413208
# torch.Size([379, 13])
# 当前step:147 验证集损失：6.874627113342285
# torch.Size([379, 13])
# 当前step:148 验证集损失：6.864418029785156
# torch.Size([379, 13])
# 当前step:149 验证集损失：6.854389190673828
# torch.Size([379, 13])
# 当前step:150 验证集损失：6.8445258140563965
# torch.Size([379, 13])
# 当前step:151 验证集损失：6.834760665893555
# torch.Size([379, 13])
# 当前step:152 验证集损失：6.825164318084717
# torch.Size([379, 13])
# 当前step:153 验证集损失：6.8156867027282715
# torch.Size([379, 13])
# 当前step:154 验证集损失：6.806285381317139
# torch.Size([379, 13])
# 当前step:155 验证集损失：6.7970194816589355
# torch.Size([379, 13])
# 当前step:156 验证集损失：6.787872791290283
# torch.Size([379, 13])
# 当前step:157 验证集损失：6.7788004875183105
# torch.Size([379, 13])
# 当前step:158 验证集损失：6.769850254058838
# torch.Size([379, 13])
# 当前step:159 验证集损失：6.761099815368652
# torch.Size([379, 13])
# 当前step:160 验证集损失：6.752453804016113
# torch.Size([379, 13])
# 当前step:161 验证集损失：6.743917942047119
# torch.Size([379, 13])
# 当前step:162 验证集损失：6.735509395599365
# torch.Size([379, 13])
# 当前step:163 验证集损失：6.727241516113281
# torch.Size([379, 13])
# 当前step:164 验证集损失：6.719113349914551
# torch.Size([379, 13])
# 当前step:165 验证集损失：6.71108865737915
# torch.Size([379, 13])
# 当前step:166 验证集损失：6.7031636238098145
# torch.Size([379, 13])
# 当前step:167 验证集损失：6.695341110229492
# torch.Size([379, 13])
# 当前step:168 验证集损失：6.687778472900391
# torch.Size([379, 13])
# 当前step:169 验证集损失：6.680387020111084
# torch.Size([379, 13])
# 当前step:170 验证集损失：6.67318058013916
# torch.Size([379, 13])
# 当前step:171 验证集损失：6.666131496429443
# torch.Size([379, 13])
# 当前step:172 验证集损失：6.659233093261719
# torch.Size([379, 13])
# 当前step:173 验证集损失：6.652552127838135
# torch.Size([379, 13])
# 当前step:174 验证集损失：6.646002769470215
# torch.Size([379, 13])
# 当前step:175 验证集损失：6.639562606811523
# torch.Size([379, 13])
# 当前step:176 验证集损失：6.63332986831665
# torch.Size([379, 13])
# 当前step:177 验证集损失：6.627236366271973
# torch.Size([379, 13])
# 当前step:178 验证集损失：6.621281623840332
# torch.Size([379, 13])
# 当前step:179 验证集损失：6.61545991897583
# torch.Size([379, 13])
# 当前step:180 验证集损失：6.609763145446777
# torch.Size([379, 13])
# 当前step:181 验证集损失：6.604228496551514
# torch.Size([379, 13])
# 当前step:182 验证集损失：6.598742961883545
# torch.Size([379, 13])
# 当前step:183 验证集损失：6.593395233154297
# torch.Size([379, 13])
# 当前step:184 验证集损失：6.588169574737549
# torch.Size([379, 13])
# 当前step:185 验证集损失：6.583065986633301
# torch.Size([379, 13])
# 当前step:186 验证集损失：6.577998638153076
# torch.Size([379, 13])
# 当前step:187 验证集损失：6.57301139831543
# torch.Size([379, 13])
# 当前step:188 验证集损失：6.568110942840576
# torch.Size([379, 13])
# 当前step:189 验证集损失：6.563276767730713
# torch.Size([379, 13])
# 当前step:190 验证集损失：6.558588981628418
# torch.Size([379, 13])
# 当前step:191 验证集损失：6.553977966308594
# torch.Size([379, 13])
# 当前step:192 验证集损失：6.549510478973389
# torch.Size([379, 13])
# 当前step:193 验证集损失：6.545048713684082
# torch.Size([379, 13])
# 当前step:194 验证集损失：6.540725231170654
# torch.Size([379, 13])
# 当前step:195 验证集损失：6.536437034606934
# torch.Size([379, 13])
# 当前step:196 验证集损失：6.53224515914917
# torch.Size([379, 13])
# 当前step:197 验证集损失：6.528192520141602
# torch.Size([379, 13])
# 当前step:198 验证集损失：6.524177074432373
# torch.Size([379, 13])
# 当前step:199 验证集损失：6.520211219787598
# torch.Size([379, 13])
# 当前step:200 验证集损失：6.516297340393066
# torch.Size([379, 13])
# 当前step:201 验证集损失：6.512476921081543
# torch.Size([379, 13])
# 当前step:202 验证集损失：6.508663654327393
# torch.Size([379, 13])
# 当前step:203 验证集损失：6.504971504211426
# torch.Size([379, 13])
# 当前step:204 验证集损失：6.5013427734375
# torch.Size([379, 13])
# 当前step:205 验证集损失：6.497714042663574
# torch.Size([379, 13])
# 当前step:206 验证集损失：6.49417781829834
# torch.Size([379, 13])
# 当前step:207 验证集损失：6.49069356918335
# torch.Size([379, 13])
# 当前step:208 验证集损失：6.487253189086914
# torch.Size([379, 13])
# 当前step:209 验证集损失：6.483941078186035
# torch.Size([379, 13])
# 当前step:210 验证集损失：6.480586528778076
# torch.Size([379, 13])
# 当前step:211 验证集损失：6.477370738983154
# torch.Size([379, 13])
# 当前step:212 验证集损失：6.4741339683532715
# torch.Size([379, 13])
# 当前step:213 验证集损失：6.471083164215088
# torch.Size([379, 13])
# 当前step:214 验证集损失：6.468013286590576
# torch.Size([379, 13])
# 当前step:215 验证集损失：6.465014934539795
# torch.Size([379, 13])
# 当前step:216 验证集损失：6.462073802947998
# torch.Size([379, 13])
# 当前step:217 验证集损失：6.4591875076293945
# torch.Size([379, 13])
# 当前step:218 验证集损失：6.4563164710998535
# torch.Size([379, 13])
# 当前step:219 验证集损失：6.453524112701416
# torch.Size([379, 13])
# 当前step:220 验证集损失：6.450736045837402
# torch.Size([379, 13])
# 当前step:221 验证集损失：6.447994232177734
# torch.Size([379, 13])
# 当前step:222 验证集损失：6.445319175720215
# torch.Size([379, 13])
# 当前step:223 验证集损失：6.442684650421143
# torch.Size([379, 13])
# 当前step:224 验证集损失：6.440123558044434
# torch.Size([379, 13])
# 当前step:225 验证集损失：6.437533855438232
# torch.Size([379, 13])
# 当前step:226 验证集损失：6.435013771057129
# torch.Size([379, 13])
# 当前step:227 验证集损失：6.432595252990723
# torch.Size([379, 13])
# 当前step:228 验证集损失：6.430123805999756
# torch.Size([379, 13])
# 当前step:229 验证集损失：6.4277448654174805
# torch.Size([379, 13])
# 当前step:230 验证集损失：6.425357341766357
# torch.Size([379, 13])
# 当前step:231 验证集损失：6.423029899597168
# torch.Size([379, 13])
# 当前step:232 验证集损失：6.420741081237793
# torch.Size([379, 13])
# 当前step:233 验证集损失：6.418502330780029
# torch.Size([379, 13])
# 当前step:234 验证集损失：6.416346549987793
# torch.Size([379, 13])
# 当前step:235 验证集损失：6.414209365844727
# torch.Size([379, 13])
# 当前step:236 验证集损失：6.412107467651367
# torch.Size([379, 13])
# 当前step:237 验证集损失：6.4100141525268555
# torch.Size([379, 13])
# 当前step:238 验证集损失：6.407970905303955
# torch.Size([379, 13])
# 当前step:239 验证集损失：6.405914783477783
# torch.Size([379, 13])
# 当前step:240 验证集损失：6.403963565826416
# torch.Size([379, 13])
# 当前step:241 验证集损失：6.401976585388184
# torch.Size([379, 13])
# 当前step:242 验证集损失：6.400063991546631
# torch.Size([379, 13])
# 当前step:243 验证集损失：6.3981547355651855
# torch.Size([379, 13])
# 当前step:244 验证集损失：6.396252632141113
# torch.Size([379, 13])
# 当前step:245 验证集损失：6.394340515136719
# torch.Size([379, 13])
# 当前step:246 验证集损失：6.3925042152404785
# torch.Size([379, 13])
# 当前step:247 验证集损失：6.390682697296143
# torch.Size([379, 13])
# 当前step:248 验证集损失：6.388835906982422
# torch.Size([379, 13])
# 当前step:249 验证集损失：6.387012481689453
# torch.Size([379, 13])
# 当前step:250 验证集损失：6.385218620300293
# torch.Size([379, 13])
# 当前step:251 验证集损失：6.383433818817139
# torch.Size([379, 13])
# 当前step:252 验证集损失：6.381641864776611
# torch.Size([379, 13])
# 当前step:253 验证集损失：6.37990665435791
# torch.Size([379, 13])
# 当前step:254 验证集损失：6.378138065338135
# torch.Size([379, 13])
# 当前step:255 验证集损失：6.376395225524902
# torch.Size([379, 13])
# 当前step:256 验证集损失：6.374701023101807
# torch.Size([379, 13])
# 当前step:257 验证集损失：6.3729939460754395
# torch.Size([379, 13])
# 当前step:258 验证集损失：6.371347904205322
# torch.Size([379, 13])
# 当前step:259 验证集损失：6.369709014892578
# torch.Size([379, 13])
# 当前step:260 验证集损失：6.368057727813721
# torch.Size([379, 13])
# 当前step:261 验证集损失：6.366437911987305
# torch.Size([379, 13])
# 当前step:262 验证集损失：6.364880084991455
# torch.Size([379, 13])
# 当前step:263 验证集损失：6.363296985626221
# torch.Size([379, 13])
# 当前step:264 验证集损失：6.361826419830322
# torch.Size([379, 13])
# 当前step:265 验证集损失：6.36037540435791
# torch.Size([379, 13])
# 当前step:266 验证集损失：6.35894250869751
# torch.Size([379, 13])
# 当前step:267 验证集损失：6.357554912567139
# torch.Size([379, 13])
# 当前step:268 验证集损失：6.356210708618164
# torch.Size([379, 13])
# 当前step:269 验证集损失：6.354897975921631
# torch.Size([379, 13])
# 当前step:270 验证集损失：6.353592395782471
# torch.Size([379, 13])
# 当前step:271 验证集损失：6.352341175079346
# torch.Size([379, 13])
# 当前step:272 验证集损失：6.3510918617248535
# torch.Size([379, 13])
# 当前step:273 验证集损失：6.349853515625
# torch.Size([379, 13])
# 当前step:274 验证集损失：6.348625659942627
# torch.Size([379, 13])
# 当前step:275 验证集损失：6.347433090209961
# torch.Size([379, 13])
# 当前step:276 验证集损失：6.346199989318848
# torch.Size([379, 13])
# 当前step:277 验证集损失：6.345045566558838
# torch.Size([379, 13])
# 当前step:278 验证集损失：6.343926906585693
# torch.Size([379, 13])
# 当前step:279 验证集损失：6.342808246612549
# torch.Size([379, 13])
# 当前step:280 验证集损失：6.341635227203369
# torch.Size([379, 13])
# 当前step:281 验证集损失：6.340555667877197
# torch.Size([379, 13])
# 当前step:282 验证集损失：6.339441776275635
# torch.Size([379, 13])
# 当前step:283 验证集损失：6.338364124298096
# torch.Size([379, 13])
# 当前step:284 验证集损失：6.3372721672058105
# torch.Size([379, 13])
# 当前step:285 验证集损失：6.336238861083984
# torch.Size([379, 13])
# 当前step:286 验证集损失：6.335205078125
# torch.Size([379, 13])
# 当前step:287 验证集损失：6.33417272567749
# torch.Size([379, 13])
# 当前step:288 验证集损失：6.333150386810303
# torch.Size([379, 13])
# 当前step:289 验证集损失：6.332119941711426
# torch.Size([379, 13])
# 当前step:290 验证集损失：6.3311028480529785
# torch.Size([379, 13])
# 当前step:291 验证集损失：6.33008337020874
# torch.Size([379, 13])
# 当前step:292 验证集损失：6.329091548919678
# torch.Size([379, 13])
# 当前step:293 验证集损失：6.328078746795654
# torch.Size([379, 13])
# 当前step:294 验证集损失：6.3271026611328125
# torch.Size([379, 13])
# 当前step:295 验证集损失：6.326085090637207
# torch.Size([379, 13])
# 当前step:296 验证集损失：6.325064182281494
# torch.Size([379, 13])
# 当前step:297 验证集损失：6.324054718017578
# torch.Size([379, 13])
# 当前step:298 验证集损失：6.323029041290283
# torch.Size([379, 13])
# 当前step:299 验证集损失：6.322026252746582
# torch.Size([379, 13])
# 当前step:300 验证集损失：6.321073055267334
# torch.Size([379, 13])
# 当前step:301 验证集损失：6.320111274719238
# torch.Size([379, 13])
# 当前step:302 验证集损失：6.31913948059082
# torch.Size([379, 13])
# 当前step:303 验证集损失：6.3182196617126465
# torch.Size([379, 13])
# 当前step:304 验证集损失：6.317298412322998
# torch.Size([379, 13])
# 当前step:305 验证集损失：6.316396713256836
# torch.Size([379, 13])
# 当前step:306 验证集损失：6.315530300140381
# torch.Size([379, 13])
# 当前step:307 验证集损失：6.314661979675293
# torch.Size([379, 13])
# 当前step:308 验证集损失：6.313809871673584
# torch.Size([379, 13])
# 当前step:309 验证集损失：6.313007354736328
# torch.Size([379, 13])
# 当前step:310 验证集损失：6.31217622756958
# torch.Size([379, 13])
# 当前step:311 验证集损失：6.311349868774414
# torch.Size([379, 13])
# 当前step:312 验证集损失：6.310552597045898
# torch.Size([379, 13])
# 当前step:313 验证集损失：6.309686183929443
# torch.Size([379, 13])
# 当前step:314 验证集损失：6.308868408203125
# torch.Size([379, 13])
# 当前step:315 验证集损失：6.308082103729248
# torch.Size([379, 13])
# 当前step:316 验证集损失：6.30723762512207
# torch.Size([379, 13])
# 当前step:317 验证集损失：6.306407928466797
# torch.Size([379, 13])
# 当前step:318 验证集损失：6.305624485015869
# torch.Size([379, 13])
# 当前step:319 验证集损失：6.304819107055664
# torch.Size([379, 13])
# 当前step:320 验证集损失：6.303991317749023
# torch.Size([379, 13])
# 当前step:321 验证集损失：6.303158760070801
# torch.Size([379, 13])
# 当前step:322 验证集损失：6.302328109741211
# torch.Size([379, 13])
# 当前step:323 验证集损失：6.301580429077148
# torch.Size([379, 13])
# 当前step:324 验证集损失：6.300777435302734
# torch.Size([379, 13])
# 当前step:325 验证集损失：6.300008296966553
# torch.Size([379, 13])
# 当前step:326 验证集损失：6.299237251281738
# torch.Size([379, 13])
# 当前step:327 验证集损失：6.298489570617676
# torch.Size([379, 13])
# 当前step:328 验证集损失：6.297708034515381
# torch.Size([379, 13])
# 当前step:329 验证集损失：6.296965599060059
# torch.Size([379, 13])
# 当前step:330 验证集损失：6.296273708343506
# torch.Size([379, 13])
# 当前step:331 验证集损失：6.295510768890381
# torch.Size([379, 13])
# 当前step:332 验证集损失：6.294820785522461
# torch.Size([379, 13])
# 当前step:333 验证集损失：6.294123649597168
# torch.Size([379, 13])
# 当前step:334 验证集损失：6.2934370040893555
# torch.Size([379, 13])
# 当前step:335 验证集损失：6.292802810668945
# torch.Size([379, 13])
# 当前step:336 验证集损失：6.292114734649658
# torch.Size([379, 13])
# 当前step:337 验证集损失：6.291459560394287
# torch.Size([379, 13])
# 当前step:338 验证集损失：6.290768623352051
# torch.Size([379, 13])
# 当前step:339 验证集损失：6.290060520172119
# torch.Size([379, 13])
# 当前step:340 验证集损失：6.289395809173584
# torch.Size([379, 13])
# 当前step:341 验证集损失：6.288693904876709
# torch.Size([379, 13])
# 当前step:342 验证集损失：6.287935256958008
# torch.Size([379, 13])
# 当前step:343 验证集损失：6.287226676940918
# torch.Size([379, 13])
# 当前step:344 验证集损失：6.286499977111816
# torch.Size([379, 13])
# 当前step:345 验证集损失：6.2857770919799805
# torch.Size([379, 13])
# 当前step:346 验证集损失：6.285057544708252
# torch.Size([379, 13])
# 当前step:347 验证集损失：6.2843170166015625
# torch.Size([379, 13])
# 当前step:348 验证集损失：6.283585071563721
# torch.Size([379, 13])
# 当前step:349 验证集损失：6.282874584197998
# torch.Size([379, 13])
# 当前step:350 验证集损失：6.2821502685546875
# torch.Size([379, 13])
# 当前step:351 验证集损失：6.281430244445801
# torch.Size([379, 13])
# 当前step:352 验证集损失：6.280741214752197
# torch.Size([379, 13])
# 当前step:353 验证集损失：6.280064582824707
# torch.Size([379, 13])
# 当前step:354 验证集损失：6.2793989181518555
# torch.Size([379, 13])
# 当前step:355 验证集损失：6.2787041664123535
# torch.Size([379, 13])
# 当前step:356 验证集损失：6.278050422668457
# torch.Size([379, 13])
# 当前step:357 验证集损失：6.277405738830566
# torch.Size([379, 13])
# 当前step:358 验证集损失：6.2767791748046875
# torch.Size([379, 13])
# 当前step:359 验证集损失：6.276121616363525
# torch.Size([379, 13])
# 当前step:360 验证集损失：6.275484085083008
# torch.Size([379, 13])
# 当前step:361 验证集损失：6.274864196777344
# torch.Size([379, 13])
# 当前step:362 验证集损失：6.274228096008301
# torch.Size([379, 13])
# 当前step:363 验证集损失：6.273617267608643
# torch.Size([379, 13])
# 当前step:364 验证集损失：6.27299165725708
# torch.Size([379, 13])
# 当前step:365 验证集损失：6.272378444671631
# torch.Size([379, 13])
# 当前step:366 验证集损失：6.2717790603637695
# torch.Size([379, 13])
# 当前step:367 验证集损失：6.271173000335693
# torch.Size([379, 13])
# 当前step:368 验证集损失：6.270538806915283
# torch.Size([379, 13])
# 当前step:369 验证集损失：6.269914627075195
# torch.Size([379, 13])
# 当前step:370 验证集损失：6.269266128540039
# torch.Size([379, 13])
# 当前step:371 验证集损失：6.268669128417969
# torch.Size([379, 13])
# 当前step:372 验证集损失：6.268019199371338
# torch.Size([379, 13])
# 当前step:373 验证集损失：6.26742696762085
# torch.Size([379, 13])
# 当前step:374 验证集损失：6.2667765617370605
# torch.Size([379, 13])
# 当前step:375 验证集损失：6.266144752502441
# torch.Size([379, 13])
# 当前step:376 验证集损失：6.265504837036133
# torch.Size([379, 13])
# 当前step:377 验证集损失：6.264860153198242
# torch.Size([379, 13])
# 当前step:378 验证集损失：6.264243125915527
# torch.Size([379, 13])
# 当前step:379 验证集损失：6.263586521148682
# torch.Size([379, 13])
# 当前step:380 验证集损失：6.2629194259643555
# torch.Size([379, 13])
# 当前step:381 验证集损失：6.262298107147217
# torch.Size([379, 13])
# 当前step:382 验证集损失：6.26163387298584
# torch.Size([379, 13])
# 当前step:383 验证集损失：6.260971546173096
# torch.Size([379, 13])
# 当前step:384 验证集损失：6.260316371917725
# torch.Size([379, 13])
# 当前step:385 验证集损失：6.2596611976623535
# torch.Size([379, 13])
# 当前step:386 验证集损失：6.25900411605835
# torch.Size([379, 13])
# 当前step:387 验证集损失：6.258326530456543
# torch.Size([379, 13])
# 当前step:388 验证集损失：6.257693767547607
# torch.Size([379, 13])
# 当前step:389 验证集损失：6.257063388824463
# torch.Size([379, 13])
# 当前step:390 验证集损失：6.256410121917725
# torch.Size([379, 13])
# 当前step:391 验证集损失：6.2557830810546875
# torch.Size([379, 13])
# 当前step:392 验证集损失：6.255166053771973
# torch.Size([379, 13])
# 当前step:393 验证集损失：6.254563808441162
# torch.Size([379, 13])
# 当前step:394 验证集损失：6.253956317901611
# torch.Size([379, 13])
# 当前step:395 验证集损失：6.253349304199219
# torch.Size([379, 13])
# 当前step:396 验证集损失：6.25277042388916
# torch.Size([379, 13])
# 当前step:397 验证集损失：6.252171039581299
# torch.Size([379, 13])
# 当前step:398 验证集损失：6.251585006713867
# torch.Size([379, 13])
# 当前step:399 验证集损失：6.251023769378662
# torch.Size([379, 13])
# 当前step:400 验证集损失：6.250491619110107
# torch.Size([379, 13])
# 当前step:401 验证集损失：6.2499775886535645
# torch.Size([379, 13])
# 当前step:402 验证集损失：6.24941873550415
# torch.Size([379, 13])
# 当前step:403 验证集损失：6.248884201049805
# torch.Size([379, 13])
# 当前step:404 验证集损失：6.248341083526611
# torch.Size([379, 13])
# 当前step:405 验证集损失：6.247750282287598
# torch.Size([379, 13])
# 当前step:406 验证集损失：6.247201919555664
# torch.Size([379, 13])
# 当前step:407 验证集损失：6.246613502502441
# torch.Size([379, 13])
# 当前step:408 验证集损失：6.24601411819458
# torch.Size([379, 13])
# 当前step:409 验证集损失：6.245397090911865
# torch.Size([379, 13])
# 当前step:410 验证集损失：6.244812488555908
# torch.Size([379, 13])
# 当前step:411 验证集损失：6.244161605834961
# torch.Size([379, 13])
# 当前step:412 验证集损失：6.243521690368652
# torch.Size([379, 13])
# 当前step:413 验证集损失：6.242888927459717
# torch.Size([379, 13])
# 当前step:414 验证集损失：6.2422661781311035
# torch.Size([379, 13])
# 当前step:415 验证集损失：6.241677284240723
# torch.Size([379, 13])
# 当前step:416 验证集损失：6.241028308868408
# torch.Size([379, 13])
# 当前step:417 验证集损失：6.240373134613037
# torch.Size([379, 13])
# 当前step:418 验证集损失：6.239745616912842
# torch.Size([379, 13])
# 当前step:419 验证集损失：6.239128112792969
# torch.Size([379, 13])
# 当前step:420 验证集损失：6.238504886627197
# torch.Size([379, 13])
# 当前step:421 验证集损失：6.237949848175049
# torch.Size([379, 13])
# 当前step:422 验证集损失：6.237371921539307
# torch.Size([379, 13])
# 当前step:423 验证集损失：6.236778259277344
# torch.Size([379, 13])
# 当前step:424 验证集损失：6.2362213134765625
# torch.Size([379, 13])
# 当前step:425 验证集损失：6.235659599304199
# torch.Size([379, 13])
# 当前step:426 验证集损失：6.2351250648498535
# torch.Size([379, 13])
# 当前step:427 验证集损失：6.234575271606445
# torch.Size([379, 13])
# 当前step:428 验证集损失：6.23405647277832
# torch.Size([379, 13])
# 当前step:429 验证集损失：6.233555793762207
# torch.Size([379, 13])
# 当前step:430 验证集损失：6.233059883117676
# torch.Size([379, 13])
# 当前step:431 验证集损失：6.232558727264404
# torch.Size([379, 13])
# 当前step:432 验证集损失：6.23207950592041
# torch.Size([379, 13])
# 当前step:433 验证集损失：6.231556415557861
# torch.Size([379, 13])
# 当前step:434 验证集损失：6.231091499328613
# torch.Size([379, 13])
# 当前step:435 验证集损失：6.230635166168213
# torch.Size([379, 13])
# 当前step:436 验证集损失：6.230119705200195
# torch.Size([379, 13])
# 当前step:437 验证集损失：6.229644775390625
# torch.Size([379, 13])
# 当前step:438 验证集损失：6.229140758514404
# torch.Size([379, 13])
# 当前step:439 验证集损失：6.228614330291748
# torch.Size([379, 13])
# 当前step:440 验证集损失：6.228111267089844
# torch.Size([379, 13])
# 当前step:441 验证集损失：6.227555274963379
# torch.Size([379, 13])
# 当前step:442 验证集损失：6.226987361907959
# torch.Size([379, 13])
# 当前step:443 验证集损失：6.226419448852539
# torch.Size([379, 13])
# 当前step:444 验证集损失：6.225837230682373
# torch.Size([379, 13])
# 当前step:445 验证集损失：6.22526741027832
# torch.Size([379, 13])
# 当前step:446 验证集损失：6.224678039550781
# torch.Size([379, 13])
# 当前step:447 验证集损失：6.224122047424316
# torch.Size([379, 13])
# 当前step:448 验证集损失：6.2235188484191895
# torch.Size([379, 13])
# 当前step:449 验证集损失：6.222943305969238
# torch.Size([379, 13])
# 当前step:450 验证集损失：6.222399711608887
# torch.Size([379, 13])
# 当前step:451 验证集损失：6.221821308135986
# torch.Size([379, 13])
# 当前step:452 验证集损失：6.221246242523193
# torch.Size([379, 13])
# 当前step:453 验证集损失：6.220651626586914
# torch.Size([379, 13])
# 当前step:454 验证集损失：6.220115661621094
# torch.Size([379, 13])
# 当前step:455 验证集损失：6.219514846801758
# torch.Size([379, 13])
# 当前step:456 验证集损失：6.2189764976501465
# torch.Size([379, 13])
# 当前step:457 验证集损失：6.218429088592529
# torch.Size([379, 13])
# 当前step:458 验证集损失：6.217841148376465
# torch.Size([379, 13])
# 当前step:459 验证集损失：6.217293739318848
# torch.Size([379, 13])
# 当前step:460 验证集损失：6.216717720031738
# torch.Size([379, 13])
# 当前step:461 验证集损失：6.2161335945129395
# torch.Size([379, 13])
# 当前step:462 验证集损失：6.215572357177734
# torch.Size([379, 13])
# 当前step:463 验证集损失：6.215024948120117
# torch.Size([379, 13])
# 当前step:464 验证集损失：6.214472770690918
# torch.Size([379, 13])
# 当前step:465 验证集损失：6.21390962600708
# torch.Size([379, 13])
# 当前step:466 验证集损失：6.213350772857666
# torch.Size([379, 13])
# 当前step:467 验证集损失：6.212802410125732
# torch.Size([379, 13])
# 当前step:468 验证集损失：6.212247848510742
# torch.Size([379, 13])
# 当前step:469 验证集损失：6.211711406707764
# torch.Size([379, 13])
# 当前step:470 验证集损失：6.211197376251221
# torch.Size([379, 13])
# 当前step:471 验证集损失：6.210675239562988
# torch.Size([379, 13])
# 当前step:472 验证集损失：6.210108280181885
# torch.Size([379, 13])
# 当前step:473 验证集损失：6.209591865539551
# torch.Size([379, 13])
# 当前step:474 验证集损失：6.209057331085205
# torch.Size([379, 13])
# 当前step:475 验证集损失：6.2084760665893555
# torch.Size([379, 13])
# 当前step:476 验证集损失：6.207976818084717
# torch.Size([379, 13])
# 当前step:477 验证集损失：6.207454204559326
# torch.Size([379, 13])
# 当前step:478 验证集损失：6.206965446472168
# torch.Size([379, 13])
# 当前step:479 验证集损失：6.206435203552246
# torch.Size([379, 13])
# 当前step:480 验证集损失：6.2059326171875
# torch.Size([379, 13])
# 当前step:481 验证集损失：6.205374240875244
# torch.Size([379, 13])
# 当前step:482 验证集损失：6.204849720001221
# torch.Size([379, 13])
# 当前step:483 验证集损失：6.204368591308594
# torch.Size([379, 13])
# 当前step:484 验证集损失：6.203845977783203
# torch.Size([379, 13])
# 当前step:485 验证集损失：6.203334808349609
# torch.Size([379, 13])
# 当前step:486 验证集损失：6.202800750732422
# torch.Size([379, 13])
# 当前step:487 验证集损失：6.202244281768799
# torch.Size([379, 13])
# 当前step:488 验证集损失：6.201700687408447
# torch.Size([379, 13])
# 当前step:489 验证集损失：6.201160907745361
# torch.Size([379, 13])
# 当前step:490 验证集损失：6.200623035430908
# torch.Size([379, 13])
# 当前step:491 验证集损失：6.200089454650879
# torch.Size([379, 13])
# 当前step:492 验证集损失：6.19954252243042
# torch.Size([379, 13])
# 当前step:493 验证集损失：6.198974609375
# torch.Size([379, 13])
# 当前step:494 验证集损失：6.198431968688965
# torch.Size([379, 13])
# 当前step:495 验证集损失：6.197937965393066
# torch.Size([379, 13])
# 当前step:496 验证集损失：6.197406768798828
# torch.Size([379, 13])
# 当前step:497 验证集损失：6.196911811828613
# torch.Size([379, 13])
# 当前step:498 验证集损失：6.196390151977539
# torch.Size([379, 13])
# 当前step:499 验证集损失：6.195868015289307
# torch.Size([379, 13])
# 当前step:500 验证集损失：6.195382595062256
# torch.Size([379, 13])
# 当前step:501 验证集损失：6.194894790649414
# torch.Size([379, 13])
# 当前step:502 验证集损失：6.1943678855896
# torch.Size([379, 13])
# 当前step:503 验证集损失：6.1938557624816895
# torch.Size([379, 13])
# 当前step:504 验证集损失：6.193349838256836
# torch.Size([379, 13])
# 当前step:505 验证集损失：6.192806243896484
# torch.Size([379, 13])
# 当前step:506 验证集损失：6.192305564880371
# torch.Size([379, 13])
# 当前step:507 验证集损失：6.191770076751709
# torch.Size([379, 13])
# 当前step:508 验证集损失：6.191242694854736
# torch.Size([379, 13])
# 当前step:509 验证集损失：6.1907267570495605
# torch.Size([379, 13])
# 当前step:510 验证集损失：6.190203666687012
# torch.Size([379, 13])
# 当前step:511 验证集损失：6.189691543579102
# torch.Size([379, 13])
# 当前step:512 验证集损失：6.189122200012207
# torch.Size([379, 13])
# 当前step:513 验证集损失：6.188631057739258
# torch.Size([379, 13])
# 当前step:514 验证集损失：6.188075065612793
# torch.Size([379, 13])
# 当前step:515 验证集损失：6.187540054321289
# torch.Size([379, 13])
# 当前step:516 验证集损失：6.187004566192627
# torch.Size([379, 13])
# 当前step:517 验证集损失：6.186520576477051
# torch.Size([379, 13])
# 当前step:518 验证集损失：6.185990810394287
# torch.Size([379, 13])
# 当前step:519 验证集损失：6.18546199798584
# torch.Size([379, 13])
# 当前step:520 验证集损失：6.184937953948975
# torch.Size([379, 13])
# 当前step:521 验证集损失：6.184460639953613
# torch.Size([379, 13])
# 当前step:522 验证集损失：6.183933258056641
# torch.Size([379, 13])
# 当前step:523 验证集损失：6.183436870574951
# torch.Size([379, 13])
# 当前step:524 验证集损失：6.182979583740234
# torch.Size([379, 13])
# 当前step:525 验证集损失：6.1824822425842285
# torch.Size([379, 13])
# 当前step:526 验证集损失：6.181965351104736
# torch.Size([379, 13])
# 当前step:527 验证集损失：6.1814680099487305
# torch.Size([379, 13])
# 当前step:528 验证集损失：6.181005001068115
# torch.Size([379, 13])
# 当前step:529 验证集损失：6.1805219650268555
# torch.Size([379, 13])
# 当前step:530 验证集损失：6.180026054382324
# torch.Size([379, 13])
# 当前step:531 验证集损失：6.179591655731201
# torch.Size([379, 13])
# 当前step:532 验证集损失：6.179104804992676
# torch.Size([379, 13])
# 当前step:533 验证集损失：6.178628444671631
# torch.Size([379, 13])
# 当前step:534 验证集损失：6.178133487701416
# torch.Size([379, 13])
# 当前step:535 验证集损失：6.177634239196777
# torch.Size([379, 13])
# 当前step:536 验证集损失：6.177170753479004
# torch.Size([379, 13])
# 当前step:537 验证集损失：6.176678657531738
# torch.Size([379, 13])
# 当前step:538 验证集损失：6.176196098327637
# torch.Size([379, 13])
# 当前step:539 验证集损失：6.175693988800049
# torch.Size([379, 13])
# 当前step:540 验证集损失：6.175206661224365
# torch.Size([379, 13])
# 当前step:541 验证集损失：6.174696922302246
# torch.Size([379, 13])
# 当前step:542 验证集损失：6.1742095947265625
# torch.Size([379, 13])
# 当前step:543 验证集损失：6.173712253570557
# torch.Size([379, 13])
# 当前step:544 验证集损失：6.173220157623291
# torch.Size([379, 13])
# 当前step:545 验证集损失：6.172725677490234
# torch.Size([379, 13])
# 当前step:546 验证集损失：6.172245025634766
# torch.Size([379, 13])
# 当前step:547 验证集损失：6.171751022338867
# torch.Size([379, 13])
# 当前step:548 验证集损失：6.171263217926025
# torch.Size([379, 13])
# 当前step:549 验证集损失：6.170788764953613
# torch.Size([379, 13])
# 当前step:550 验证集损失：6.1702656745910645
# torch.Size([379, 13])
# 当前step:551 验证集损失：6.169783115386963
# torch.Size([379, 13])
# 当前step:552 验证集损失：6.169321060180664
# torch.Size([379, 13])
# 当前step:553 验证集损失：6.168829441070557
# torch.Size([379, 13])
# 当前step:554 验证集损失：6.168350696563721
# torch.Size([379, 13])
# 当前step:555 验证集损失：6.167883396148682
# torch.Size([379, 13])
# 当前step:556 验证集损失：6.167421340942383
# torch.Size([379, 13])
# 当前step:557 验证集损失：6.166969299316406
# torch.Size([379, 13])
# 当前step:558 验证集损失：6.166543960571289
# torch.Size([379, 13])
# 当前step:559 验证集损失：6.166071891784668
# torch.Size([379, 13])
# 当前step:560 验证集损失：6.165587425231934
# torch.Size([379, 13])
# 当前step:561 验证集损失：6.165125370025635
# torch.Size([379, 13])
# 当前step:562 验证集损失：6.164660453796387
# torch.Size([379, 13])
# 当前step:563 验证集损失：6.164167881011963
# torch.Size([379, 13])
# 当前step:564 验证集损失：6.163717746734619
# torch.Size([379, 13])
# 当前step:565 验证集损失：6.163190841674805
# torch.Size([379, 13])
# 当前step:566 验证集损失：6.162674903869629
# torch.Size([379, 13])
# 当前step:567 验证集损失：6.162211894989014
# torch.Size([379, 13])
# 当前step:568 验证集损失：6.161715984344482
# torch.Size([379, 13])
# 当前step:569 验证集损失：6.161245822906494
# torch.Size([379, 13])
# 当前step:570 验证集损失：6.160747051239014
# torch.Size([379, 13])
# 当前step:571 验证集损失：6.160265922546387
# torch.Size([379, 13])
# 当前step:572 验证集损失：6.159805774688721
# torch.Size([379, 13])
# 当前step:573 验证集损失：6.159327030181885
# torch.Size([379, 13])
# 当前step:574 验证集损失：6.158852577209473
# torch.Size([379, 13])
# 当前step:575 验证集损失：6.1583571434021
# torch.Size([379, 13])
# 当前step:576 验证集损失：6.1578545570373535
# torch.Size([379, 13])
# 当前step:577 验证集损失：6.1573567390441895
# torch.Size([379, 13])
# 当前step:578 验证集损失：6.15688419342041
# torch.Size([379, 13])
# 当前step:579 验证集损失：6.156373977661133
# torch.Size([379, 13])
# 当前step:580 验证集损失：6.155905723571777
# torch.Size([379, 13])
# 当前step:581 验证集损失：6.155427932739258
# torch.Size([379, 13])
# 当前step:582 验证集损失：6.154967308044434
# torch.Size([379, 13])
# 当前step:583 验证集损失：6.1545233726501465
# torch.Size([379, 13])
# 当前step:584 验证集损失：6.154064178466797
# torch.Size([379, 13])
# 当前step:585 验证集损失：6.1536173820495605
# torch.Size([379, 13])
# 当前step:586 验证集损失：6.153208255767822
# torch.Size([379, 13])
# 当前step:587 验证集损失：6.152797698974609
# torch.Size([379, 13])
# 当前step:588 验证集损失：6.152371406555176
# torch.Size([379, 13])
# 当前step:589 验证集损失：6.151924133300781
# torch.Size([379, 13])
# 当前step:590 验证集损失：6.1514811515808105
# torch.Size([379, 13])
# 当前step:591 验证集损失：6.151069641113281
# torch.Size([379, 13])
# 当前step:592 验证集损失：6.150632381439209
# torch.Size([379, 13])
# 当前step:593 验证集损失：6.150207996368408
# torch.Size([379, 13])
# 当前step:594 验证集损失：6.149761199951172
# torch.Size([379, 13])
# 当前step:595 验证集损失：6.149292945861816
# torch.Size([379, 13])
# 当前step:596 验证集损失：6.148793697357178
# torch.Size([379, 13])
# 当前step:597 验证集损失：6.148316860198975
# torch.Size([379, 13])
# 当前step:598 验证集损失：6.147818088531494
# torch.Size([379, 13])
# 当前step:599 验证集损失：6.147331714630127
# torch.Size([379, 13])
# 当前step:600 验证集损失：6.1468424797058105
# torch.Size([379, 13])
# 当前step:601 验证集损失：6.146337509155273
# torch.Size([379, 13])
# 当前step:602 验证集损失：6.145791530609131
# torch.Size([379, 13])
# 当前step:603 验证集损失：6.1453022956848145
# torch.Size([379, 13])
# 当前step:604 验证集损失：6.1447930335998535
# torch.Size([379, 13])
# 当前step:605 验证集损失：6.144282341003418
# torch.Size([379, 13])
# 当前step:606 验证集损失：6.143764019012451
# torch.Size([379, 13])
# 当前step:607 验证集损失：6.1433000564575195
# torch.Size([379, 13])
# 当前step:608 验证集损失：6.142795085906982
# torch.Size([379, 13])
# 当前step:609 验证集损失：6.1423163414001465
# torch.Size([379, 13])
# 当前step:610 验证集损失：6.141863822937012
# torch.Size([379, 13])
# 当前step:611 验证集损失：6.141384601593018
# torch.Size([379, 13])
# 当前step:612 验证集损失：6.140878677368164
# torch.Size([379, 13])
# 当前step:613 验证集损失：6.140405654907227
# torch.Size([379, 13])
# 当前step:614 验证集损失：6.139984607696533
# torch.Size([379, 13])
# 当前step:615 验证集损失：6.139540672302246
# torch.Size([379, 13])
# 当前step:616 验证集损失：6.139071941375732
# torch.Size([379, 13])
# 当前step:617 验证集损失：6.1386332511901855
# torch.Size([379, 13])
# 当前step:618 验证集损失：6.1381916999816895
# torch.Size([379, 13])
# 当前step:619 验证集损失：6.137754917144775
# torch.Size([379, 13])
# 当前step:620 验证集损失：6.137301921844482
# torch.Size([379, 13])
# 当前step:621 验证集损失：6.136823654174805
# torch.Size([379, 13])
# 当前step:622 验证集损失：6.136382579803467
# torch.Size([379, 13])
# 当前step:623 验证集损失：6.135947227478027
# torch.Size([379, 13])
# 当前step:624 验证集损失：6.1355156898498535
# torch.Size([379, 13])
# 当前step:625 验证集损失：6.135108947753906
# torch.Size([379, 13])
# 当前step:626 验证集损失：6.134681701660156
# torch.Size([379, 13])
# 当前step:627 验证集损失：6.1342339515686035
# torch.Size([379, 13])
# 当前step:628 验证集损失：6.133781433105469
# torch.Size([379, 13])
# 当前step:629 验证集损失：6.1333417892456055
# torch.Size([379, 13])
# 当前step:630 验证集损失：6.132878303527832
# torch.Size([379, 13])
# 当前step:631 验证集损失：6.13237190246582
# torch.Size([379, 13])
# 当前step:632 验证集损失：6.131892204284668
# torch.Size([379, 13])
# 当前step:633 验证集损失：6.131377220153809
# torch.Size([379, 13])
# 当前step:634 验证集损失：6.130855083465576
# torch.Size([379, 13])
# 当前step:635 验证集损失：6.130360126495361
# torch.Size([379, 13])
# 当前step:636 验证集损失：6.129871845245361
# torch.Size([379, 13])
# 当前step:637 验证集损失：6.129382133483887
# torch.Size([379, 13])
# 当前step:638 验证集损失：6.128871440887451
# torch.Size([379, 13])
# 当前step:639 验证集损失：6.128427982330322
# torch.Size([379, 13])
# 当前step:640 验证集损失：6.128014087677002
# torch.Size([379, 13])
# 当前step:641 验证集损失：6.127572059631348
# torch.Size([379, 13])
# 当前step:642 验证集损失：6.12717342376709
# torch.Size([379, 13])
# 当前step:643 验证集损失：6.126803398132324
# torch.Size([379, 13])
# 当前step:644 验证集损失：6.126410961151123
# torch.Size([379, 13])
# 当前step:645 验证集损失：6.126080513000488
# torch.Size([379, 13])
# 当前step:646 验证集损失：6.1257219314575195
# torch.Size([379, 13])
# 当前step:647 验证集损失：6.125381946563721
# torch.Size([379, 13])
# 当前step:648 验证集损失：6.124983310699463
# torch.Size([379, 13])
# 当前step:649 验证集损失：6.124634265899658
# torch.Size([379, 13])
# 当前step:650 验证集损失：6.124241352081299
# torch.Size([379, 13])
# 当前step:651 验证集损失：6.12388277053833
# torch.Size([379, 13])
# 当前step:652 验证集损失：6.123473644256592
# torch.Size([379, 13])
# 当前step:653 验证集损失：6.1230573654174805
# torch.Size([379, 13])
# 当前step:654 验证集损失：6.122591018676758
# torch.Size([379, 13])
# 当前step:655 验证集损失：6.12213134765625
# torch.Size([379, 13])
# 当前step:656 验证集损失：6.121634483337402
# torch.Size([379, 13])
# 当前step:657 验证集损失：6.121121406555176
# torch.Size([379, 13])
# 当前step:658 验证集损失：6.120604515075684
# torch.Size([379, 13])
# 当前step:659 验证集损失：6.1201066970825195
# torch.Size([379, 13])
# 当前step:660 验证集损失：6.11958122253418
# torch.Size([379, 13])
# 当前step:661 验证集损失：6.119070529937744
# torch.Size([379, 13])
# 当前step:662 验证集损失：6.118589878082275
# torch.Size([379, 13])
# 当前step:663 验证集损失：6.118068218231201
# torch.Size([379, 13])
# 当前step:664 验证集损失：6.117557048797607
# torch.Size([379, 13])
# 当前step:665 验证集损失：6.117092609405518
# torch.Size([379, 13])
# 当前step:666 验证集损失：6.116652488708496
# torch.Size([379, 13])
# 当前step:667 验证集损失：6.116184711456299
# torch.Size([379, 13])
# 当前step:668 验证集损失：6.115795135498047
# torch.Size([379, 13])
# 当前step:669 验证集损失：6.115316390991211
# torch.Size([379, 13])
# 当前step:670 验证集损失：6.1149187088012695
# torch.Size([379, 13])
# 当前step:671 验证集损失：6.114530563354492
# torch.Size([379, 13])
# 当前step:672 验证集损失：6.114131927490234
# torch.Size([379, 13])
# 当前step:673 验证集损失：6.113709926605225
# torch.Size([379, 13])
# 当前step:674 验证集损失：6.113308906555176
# torch.Size([379, 13])
# 当前step:675 验证集损失：6.11286735534668
# torch.Size([379, 13])
# 当前step:676 验证集损失：6.112485885620117
# torch.Size([379, 13])
# 当前step:677 验证集损失：6.112062931060791
# torch.Size([379, 13])
# 当前step:678 验证集损失：6.11164665222168
# torch.Size([379, 13])
# 当前step:679 验证集损失：6.111230850219727
# torch.Size([379, 13])
# 当前step:680 验证集损失：6.1107707023620605
# torch.Size([379, 13])
# 当前step:681 验证集损失：6.11034631729126
# torch.Size([379, 13])
# 当前step:682 验证集损失：6.10991907119751
# torch.Size([379, 13])
# 当前step:683 验证集损失：6.1094889640808105
# torch.Size([379, 13])
# 当前step:684 验证集损失：6.109058380126953
# torch.Size([379, 13])
# 当前step:685 验证集损失：6.1085896492004395
# torch.Size([379, 13])
# 当前step:686 验证集损失：6.108120918273926
# torch.Size([379, 13])
# 当前step:687 验证集损失：6.107635974884033
# torch.Size([379, 13])
# 当前step:688 验证集损失：6.107165813446045
# torch.Size([379, 13])
# 当前step:689 验证集损失：6.106659889221191
# torch.Size([379, 13])
# 当前step:690 验证集损失：6.106213092803955
# torch.Size([379, 13])
# 当前step:691 验证集损失：6.105708599090576
# torch.Size([379, 13])
# 当前step:692 验证集损失：6.105247974395752
# torch.Size([379, 13])
# 当前step:693 验证集损失：6.1047844886779785
# torch.Size([379, 13])
# 当前step:694 验证集损失：6.104311943054199
# torch.Size([379, 13])
# 当前step:695 验证集损失：6.103868007659912
# torch.Size([379, 13])
# 当前step:696 验证集损失：6.103456497192383
# torch.Size([379, 13])
# 当前step:697 验证集损失：6.103007793426514
# torch.Size([379, 13])
# 当前step:698 验证集损失：6.102581024169922
# torch.Size([379, 13])
# 当前step:699 验证集损失：6.1021528244018555
# torch.Size([379, 13])
# 当前step:700 验证集损失：6.101741790771484
# torch.Size([379, 13])
# 当前step:701 验证集损失：6.101319789886475
# torch.Size([379, 13])
# 当前step:702 验证集损失：6.100889205932617
# torch.Size([379, 13])
# 当前step:703 验证集损失：6.100477695465088
# torch.Size([379, 13])
# 当前step:704 验证集损失：6.100102424621582
# torch.Size([379, 13])
# 当前step:705 验证集损失：6.099684238433838
# torch.Size([379, 13])
# 当前step:706 验证集损失：6.099250793457031
# torch.Size([379, 13])
# 当前step:707 验证集损失：6.098825454711914
# torch.Size([379, 13])
# 当前step:708 验证集损失：6.098370552062988
# torch.Size([379, 13])
# 当前step:709 验证集损失：6.09791374206543
# torch.Size([379, 13])
# 当前step:710 验证集损失：6.097489833831787
# torch.Size([379, 13])
# 当前step:711 验证集损失：6.097046852111816
# torch.Size([379, 13])
# 当前step:712 验证集损失：6.096645832061768
# torch.Size([379, 13])
# 当前step:713 验证集损失：6.096218109130859
# torch.Size([379, 13])
# 当前step:714 验证集损失：6.095765113830566
# torch.Size([379, 13])
# 当前step:715 验证集损失：6.095341682434082
# torch.Size([379, 13])
# 当前step:716 验证集损失：6.0948872566223145
# torch.Size([379, 13])
# 当前step:717 验证集损失：6.094493389129639
# torch.Size([379, 13])
# 当前step:718 验证集损失：6.09409761428833
# torch.Size([379, 13])
# 当前step:719 验证集损失：6.093635082244873
# torch.Size([379, 13])
# 当前step:720 验证集损失：6.093231678009033
# torch.Size([379, 13])
# 当前step:721 验证集损失：6.092830657958984
# torch.Size([379, 13])
# 当前step:722 验证集损失：6.092403411865234
# torch.Size([379, 13])
# 当前step:723 验证集损失：6.091965675354004
# torch.Size([379, 13])
# 当前step:724 验证集损失：6.091531753540039
# torch.Size([379, 13])
# 当前step:725 验证集损失：6.091098308563232
# torch.Size([379, 13])
# 当前step:726 验证集损失：6.0906901359558105
# torch.Size([379, 13])
# 当前step:727 验证集损失：6.090244770050049
# torch.Size([379, 13])
# 当前step:728 验证集损失：6.089831352233887
# torch.Size([379, 13])
# 当前step:729 验证集损失：6.089385986328125
# torch.Size([379, 13])
# 当前step:730 验证集损失：6.088924884796143
# torch.Size([379, 13])
# 当前step:731 验证集损失：6.088486671447754
# torch.Size([379, 13])
# 当前step:732 验证集损失：6.088019371032715
# torch.Size([379, 13])
# 当前step:733 验证集损失：6.087543487548828
# torch.Size([379, 13])
# 当前step:734 验证集损失：6.087066650390625
# torch.Size([379, 13])
# 当前step:735 验证集损失：6.0865888595581055
# torch.Size([379, 13])
# 当前step:736 验证集损失：6.086124420166016
# torch.Size([379, 13])
# 当前step:737 验证集损失：6.08563756942749
# torch.Size([379, 13])
# 当前step:738 验证集损失：6.085203170776367
# torch.Size([379, 13])
# 当前step:739 验证集损失：6.084722995758057
# torch.Size([379, 13])
# 当前step:740 验证集损失：6.084287166595459
# torch.Size([379, 13])
# 当前step:741 验证集损失：6.083827018737793
# torch.Size([379, 13])
# 当前step:742 验证集损失：6.0833940505981445
# torch.Size([379, 13])
# 当前step:743 验证集损失：6.0829925537109375
# torch.Size([379, 13])
# 当前step:744 验证集损失：6.082568168640137
# torch.Size([379, 13])
# 当前step:745 验证集损失：6.082152366638184
# torch.Size([379, 13])
# 当前step:746 验证集损失：6.081764221191406
# torch.Size([379, 13])
# 当前step:747 验证集损失：6.081313133239746
# torch.Size([379, 13])
# 当前step:748 验证集损失：6.080882549285889
# torch.Size([379, 13])
# 当前step:749 验证集损失：6.080442428588867
# torch.Size([379, 13])
# 当前step:750 验证集损失：6.080007076263428
# torch.Size([379, 13])
# 当前step:751 验证集损失：6.079584121704102
# torch.Size([379, 13])
# 当前step:752 验证集损失：6.079139232635498
# torch.Size([379, 13])
# 当前step:753 验证集损失：6.078758716583252
# torch.Size([379, 13])
# 当前step:754 验证集损失：6.078341484069824
# torch.Size([379, 13])
# 当前step:755 验证集损失：6.077920436859131
# torch.Size([379, 13])
# 当前step:756 验证集损失：6.077489376068115
# torch.Size([379, 13])
# 当前step:757 验证集损失：6.077090740203857
# torch.Size([379, 13])
# 当前step:758 验证集损失：6.076664447784424
# torch.Size([379, 13])
# 当前step:759 验证集损失：6.076253890991211
# torch.Size([379, 13])
# 当前step:760 验证集损失：6.075866222381592
# torch.Size([379, 13])
# 当前step:761 验证集损失：6.075423240661621
# torch.Size([379, 13])
# 当前step:762 验证集损失：6.0750298500061035
# torch.Size([379, 13])
# 当前step:763 验证集损失：6.074583530426025
# torch.Size([379, 13])
# 当前step:764 验证集损失：6.074194431304932
# torch.Size([379, 13])
# 当前step:765 验证集损失：6.073793411254883
# torch.Size([379, 13])
# 当前step:766 验证集损失：6.073418617248535
# torch.Size([379, 13])
# 当前step:767 验证集损失：6.073051929473877
# torch.Size([379, 13])
# 当前step:768 验证集损失：6.07264518737793
# torch.Size([379, 13])
# 当前step:769 验证集损失：6.072216510772705
# torch.Size([379, 13])
# 当前step:770 验证集损失：6.071825981140137
# torch.Size([379, 13])
# 当前step:771 验证集损失：6.0714240074157715
# torch.Size([379, 13])
# 当前step:772 验证集损失：6.071065425872803
# torch.Size([379, 13])
# 当前step:773 验证集损失：6.070683479309082
# torch.Size([379, 13])
# 当前step:774 验证集损失：6.070272922515869
# torch.Size([379, 13])
# 当前step:775 验证集损失：6.06988000869751
# torch.Size([379, 13])
# 当前step:776 验证集损失：6.0694780349731445
# torch.Size([379, 13])
# 当前step:777 验证集损失：6.069090843200684
# torch.Size([379, 13])
# 当前step:778 验证集损失：6.068697452545166
# torch.Size([379, 13])
# 当前step:779 验证集损失：6.068309307098389
# torch.Size([379, 13])
# 当前step:780 验证集损失：6.067900657653809
# torch.Size([379, 13])
# 当前step:781 验证集损失：6.067498207092285
# torch.Size([379, 13])
# 当前step:782 验证集损失：6.067071437835693
# torch.Size([379, 13])
# 当前step:783 验证集损失：6.066684246063232
# torch.Size([379, 13])
# 当前step:784 验证集损失：6.0662841796875
# torch.Size([379, 13])
# 当前step:785 验证集损失：6.065881252288818
# torch.Size([379, 13])
# 当前step:786 验证集损失：6.0655198097229
# torch.Size([379, 13])
# 当前step:787 验证集损失：6.065127849578857
# torch.Size([379, 13])
# 当前step:788 验证集损失：6.064695835113525
# torch.Size([379, 13])
# 当前step:789 验证集损失：6.064278602600098
# torch.Size([379, 13])
# 当前step:790 验证集损失：6.0638747215271
# torch.Size([379, 13])
# 当前step:791 验证集损失：6.063449859619141
# torch.Size([379, 13])
# 当前step:792 验证集损失：6.06300163269043
# torch.Size([379, 13])
# 当前step:793 验证集损失：6.0626091957092285
# torch.Size([379, 13])
# 当前step:794 验证集损失：6.062216758728027
# torch.Size([379, 13])
# 当前step:795 验证集损失：6.061798095703125
# torch.Size([379, 13])
# 当前step:796 验证集损失：6.06144380569458
# torch.Size([379, 13])
# 当前step:797 验证集损失：6.061058521270752
# torch.Size([379, 13])
# 当前step:798 验证集损失：6.060676097869873
# torch.Size([379, 13])
# 当前step:799 验证集损失：6.060296535491943
# torch.Size([379, 13])
# 当前step:800 验证集损失：6.059902667999268
# torch.Size([379, 13])
# 当前step:801 验证集损失：6.0595316886901855
# torch.Size([379, 13])
# 当前step:802 验证集损失：6.059141635894775
# torch.Size([379, 13])
# 当前step:803 验证集损失：6.058757781982422
# torch.Size([379, 13])
# 当前step:804 验证集损失：6.0583648681640625
# torch.Size([379, 13])
# 当前step:805 验证集损失：6.057925701141357
# torch.Size([379, 13])
# 当前step:806 验证集损失：6.057523250579834
# torch.Size([379, 13])
# 当前step:807 验证集损失：6.057063102722168
# torch.Size([379, 13])
# 当前step:808 验证集损失：6.056648254394531
# torch.Size([379, 13])
# 当前step:809 验证集损失：6.056225776672363
# torch.Size([379, 13])
# 当前step:810 验证集损失：6.055777072906494
# torch.Size([379, 13])
# 当前step:811 验证集损失：6.0553412437438965
# torch.Size([379, 13])
# 当前step:812 验证集损失：6.054963111877441
# torch.Size([379, 13])
# 当前step:813 验证集损失：6.054526329040527
# torch.Size([379, 13])
# 当前step:814 验证集损失：6.054103851318359
# torch.Size([379, 13])
# 当前step:815 验证集损失：6.05368709564209
# torch.Size([379, 13])
# 当前step:816 验证集损失：6.0533037185668945
# torch.Size([379, 13])
# 当前step:817 验证集损失：6.052940845489502
# torch.Size([379, 13])
# 当前step:818 验证集损失：6.052561283111572
# torch.Size([379, 13])
# 当前step:819 验证集损失：6.052250385284424
# torch.Size([379, 13])
# 当前step:820 验证集损失：6.051937580108643
# torch.Size([379, 13])
# 当前step:821 验证集损失：6.051630973815918
# torch.Size([379, 13])
# 当前step:822 验证集损失：6.051321506500244
# torch.Size([379, 13])
# 当前step:823 验证集损失：6.051019191741943
# torch.Size([379, 13])
# 当前step:824 验证集损失：6.0507659912109375
# torch.Size([379, 13])
# 当前step:825 验证集损失：6.050416469573975
# torch.Size([379, 13])
# 当前step:826 验证集损失：6.050097465515137
# torch.Size([379, 13])
# 当前step:827 验证集损失：6.049808979034424
# torch.Size([379, 13])
# 当前step:828 验证集损失：6.049445152282715
# torch.Size([379, 13])
# 当前step:829 验证集损失：6.049101829528809
# torch.Size([379, 13])
# 当前step:830 验证集损失：6.048710346221924
# torch.Size([379, 13])
# 当前step:831 验证集损失：6.048282146453857
# torch.Size([379, 13])
# 当前step:832 验证集损失：6.047858715057373
# torch.Size([379, 13])
# 当前step:833 验证集损失：6.047448635101318
# torch.Size([379, 13])
# 当前step:834 验证集损失：6.046966552734375
# torch.Size([379, 13])
# 当前step:835 验证集损失：6.046523094177246
# torch.Size([379, 13])
# 当前step:836 验证集损失：6.0460686683654785
# torch.Size([379, 13])
# 当前step:837 验证集损失：6.045672416687012
# torch.Size([379, 13])
# 当前step:838 验证集损失：6.045200347900391
# torch.Size([379, 13])
# 当前step:839 验证集损失：6.0447845458984375
# torch.Size([379, 13])
# 当前step:840 验证集损失：6.044378757476807
# torch.Size([379, 13])
# 当前step:841 验证集损失：6.043950080871582
# torch.Size([379, 13])
# 当前step:842 验证集损失：6.0435638427734375
# torch.Size([379, 13])
# 当前step:843 验证集损失：6.0431694984436035
# torch.Size([379, 13])
# 当前step:844 验证集损失：6.042782783508301
# torch.Size([379, 13])
# 当前step:845 验证集损失：6.042390823364258
# torch.Size([379, 13])
# 当前step:846 验证集损失：6.0420660972595215
# torch.Size([379, 13])
# 当前step:847 验证集损失：6.041686534881592
# torch.Size([379, 13])
# 当前step:848 验证集损失：6.04132604598999
# torch.Size([379, 13])
# 当前step:849 验证集损失：6.040964603424072
# torch.Size([379, 13])
# 当前step:850 验证集损失：6.040607452392578
# torch.Size([379, 13])
# 当前step:851 验证集损失：6.04022216796875
# torch.Size([379, 13])
# 当前step:852 验证集损失：6.039885520935059
# torch.Size([379, 13])
# 当前step:853 验证集损失：6.039531707763672
# torch.Size([379, 13])
# 当前step:854 验证集损失：6.039158344268799
# torch.Size([379, 13])
# 当前step:855 验证集损失：6.038808345794678
# torch.Size([379, 13])
# 当前step:856 验证集损失：6.0384087562561035
# torch.Size([379, 13])
# 当前step:857 验证集损失：6.038046836853027
# torch.Size([379, 13])
# 当前step:858 验证集损失：6.037651538848877
# torch.Size([379, 13])
# 当前step:859 验证集损失：6.037285327911377
# torch.Size([379, 13])
# 当前step:860 验证集损失：6.0368733406066895
# torch.Size([379, 13])
# 当前step:861 验证集损失：6.0365095138549805
# torch.Size([379, 13])
# 当前step:862 验证集损失：6.036136150360107
# torch.Size([379, 13])
# 当前step:863 验证集损失：6.035749912261963
# torch.Size([379, 13])
# 当前step:864 验证集损失：6.035361289978027
# torch.Size([379, 13])
# 当前step:865 验证集损失：6.034969806671143
# torch.Size([379, 13])
# 当前step:866 验证集损失：6.034601211547852
# torch.Size([379, 13])
# 当前step:867 验证集损失：6.034196853637695
# torch.Size([379, 13])
# 当前step:868 验证集损失：6.03385066986084
# torch.Size([379, 13])
# 当前step:869 验证集损失：6.033544063568115
# torch.Size([379, 13])
# 当前step:870 验证集损失：6.0332231521606445
# torch.Size([379, 13])
# 当前step:871 验证集损失：6.032902717590332
# torch.Size([379, 13])
# 当前step:872 验证集损失：6.03255033493042
# torch.Size([379, 13])
# 当前step:873 验证集损失：6.032230377197266
# torch.Size([379, 13])
# 当前step:874 验证集损失：6.031921863555908
# torch.Size([379, 13])
# 当前step:875 验证集损失：6.031569480895996
# torch.Size([379, 13])
# 当前step:876 验证集损失：6.031215190887451
# torch.Size([379, 13])
# 当前step:877 验证集损失：6.030854225158691
# torch.Size([379, 13])
# 当前step:878 验证集损失：6.030490875244141
# torch.Size([379, 13])
# 当前step:879 验证集损失：6.030158519744873
# torch.Size([379, 13])
# 当前step:880 验证集损失：6.02976655960083
# torch.Size([379, 13])
# 当前step:881 验证集损失：6.029407024383545
# torch.Size([379, 13])
# 当前step:882 验证集损失：6.029012680053711
# torch.Size([379, 13])
# 当前step:883 验证集损失：6.0286054611206055
# torch.Size([379, 13])
# 当前step:884 验证集损失：6.028226375579834
# torch.Size([379, 13])
# 当前step:885 验证集损失：6.027837753295898
# torch.Size([379, 13])
# 当前step:886 验证集损失：6.0274481773376465
# torch.Size([379, 13])
# 当前step:887 验证集损失：6.02703857421875
# torch.Size([379, 13])
# 当前step:888 验证集损失：6.026678085327148
# torch.Size([379, 13])
# 当前step:889 验证集损失：6.026313781738281
# torch.Size([379, 13])
# 当前step:890 验证集损失：6.025991916656494
# torch.Size([379, 13])
# 当前step:891 验证集损失：6.025677680969238
# torch.Size([379, 13])
# 当前step:892 验证集损失：6.025382041931152
# torch.Size([379, 13])
# 当前step:893 验证集损失：6.02508020401001
# torch.Size([379, 13])
# 当前step:894 验证集损失：6.024807453155518
# torch.Size([379, 13])
# 当前step:895 验证集损失：6.024498462677002
# torch.Size([379, 13])
# 当前step:896 验证集损失：6.024226665496826
# torch.Size([379, 13])
# 当前step:897 验证集损失：6.023932456970215
# torch.Size([379, 13])
# 当前step:898 验证集损失：6.023649215698242
# torch.Size([379, 13])
# 当前step:899 验证集损失：6.023309707641602
# torch.Size([379, 13])
# 当前step:900 验证集损失：6.023011207580566
# torch.Size([379, 13])
# 当前step:901 验证集损失：6.022684574127197
# torch.Size([379, 13])
# 当前step:902 验证集损失：6.022355556488037
# torch.Size([379, 13])
# 当前step:903 验证集损失：6.022001266479492
# torch.Size([379, 13])
# 当前step:904 验证集损失：6.021622657775879
# torch.Size([379, 13])
# 当前step:905 验证集损失：6.021242141723633
# torch.Size([379, 13])
# 当前step:906 验证集损失：6.020855903625488
# torch.Size([379, 13])
# 当前step:907 验证集损失：6.0204362869262695
# torch.Size([379, 13])
# 当前step:908 验证集损失：6.020036697387695
# torch.Size([379, 13])
# 当前step:909 验证集损失：6.0196661949157715
# torch.Size([379, 13])
# 当前step:910 验证集损失：6.019298076629639
# torch.Size([379, 13])
# 当前step:911 验证集损失：6.018921375274658
# torch.Size([379, 13])
# 当前step:912 验证集损失：6.018564701080322
# torch.Size([379, 13])
# 当前step:913 验证集损失：6.01821756362915
# torch.Size([379, 13])
# 当前step:914 验证集损失：6.017866611480713
# torch.Size([379, 13])
# 当前step:915 验证集损失：6.017549514770508
# torch.Size([379, 13])
# 当前step:916 验证集损失：6.017230987548828
# torch.Size([379, 13])
# 当前step:917 验证集损失：6.0169782638549805
# torch.Size([379, 13])
# 当前step:918 验证集损失：6.016641139984131
# torch.Size([379, 13])
# 当前step:919 验证集损失：6.016381740570068
# torch.Size([379, 13])
# 当前step:920 验证集损失：6.016081809997559
# torch.Size([379, 13])
# 当前step:921 验证集损失：6.015786647796631
# torch.Size([379, 13])
# 当前step:922 验证集损失：6.015483379364014
# torch.Size([379, 13])
# 当前step:923 验证集损失：6.0151543617248535
# torch.Size([379, 13])
# 当前step:924 验证集损失：6.014834880828857
# torch.Size([379, 13])
# 当前step:925 验证集损失：6.014470100402832
# torch.Size([379, 13])
# 当前step:926 验证集损失：6.014078140258789
# torch.Size([379, 13])
# 当前step:927 验证集损失：6.013705730438232
# torch.Size([379, 13])
# 当前step:928 验证集损失：6.013318061828613
# torch.Size([379, 13])
# 当前step:929 验证集损失：6.012892246246338
# torch.Size([379, 13])
# 当前step:930 验证集损失：6.012482166290283
# torch.Size([379, 13])
# 当前step:931 验证集损失：6.012073993682861
# torch.Size([379, 13])
# 当前step:932 验证集损失：6.011671543121338
# torch.Size([379, 13])
# 当前step:933 验证集损失：6.011273384094238
# torch.Size([379, 13])
# 当前step:934 验证集损失：6.010900020599365
# torch.Size([379, 13])
# 当前step:935 验证集损失：6.010546684265137
# torch.Size([379, 13])
# 当前step:936 验证集损失：6.01016092300415
# torch.Size([379, 13])
# 当前step:937 验证集损失：6.00981330871582
# torch.Size([379, 13])
# 当前step:938 验证集损失：6.009458065032959
# torch.Size([379, 13])
# 当前step:939 验证集损失：6.009136199951172
# torch.Size([379, 13])
# 当前step:940 验证集损失：6.008798599243164
# torch.Size([379, 13])
# 当前step:941 验证集损失：6.008469104766846
# torch.Size([379, 13])
# 当前step:942 验证集损失：6.008174896240234
# torch.Size([379, 13])
# 当前step:943 验证集损失：6.007904052734375
# torch.Size([379, 13])
# 当前step:944 验证集损失：6.007624626159668
# torch.Size([379, 13])
# 当前step:945 验证集损失：6.007350444793701
# torch.Size([379, 13])
# 当前step:946 验证集损失：6.007072925567627
# torch.Size([379, 13])
# 当前step:947 验证集损失：6.006814479827881
# torch.Size([379, 13])
# 当前step:948 验证集损失：6.006492614746094
# torch.Size([379, 13])
# 当前step:949 验证集损失：6.006228446960449
# torch.Size([379, 13])
# 当前step:950 验证集损失：6.005922794342041
# torch.Size([379, 13])
# 当前step:951 验证集损失：6.005601406097412
# torch.Size([379, 13])
# 当前step:952 验证集损失：6.005281448364258
# torch.Size([379, 13])
# 当前step:953 验证集损失：6.004952907562256
# torch.Size([379, 13])
# 当前step:954 验证集损失：6.004602432250977
# torch.Size([379, 13])
# 当前step:955 验证集损失：6.00423526763916
# torch.Size([379, 13])
# 当前step:956 验证集损失：6.0038604736328125
# torch.Size([379, 13])
# 当前step:957 验证集损失：6.003454685211182
# torch.Size([379, 13])
# 当前step:958 验证集损失：6.003067970275879
# torch.Size([379, 13])
# 当前step:959 验证集损失：6.002651691436768
# torch.Size([379, 13])
# 当前step:960 验证集损失：6.002277374267578
# torch.Size([379, 13])
# 当前step:961 验证集损失：6.001909255981445
# torch.Size([379, 13])
# 当前step:962 验证集损失：6.001554012298584
# torch.Size([379, 13])
# 当前step:963 验证集损失：6.0011982917785645
# torch.Size([379, 13])
# 当前step:964 验证集损失：6.000828266143799
# torch.Size([379, 13])
# 当前step:965 验证集损失：6.000482559204102
# torch.Size([379, 13])
# 当前step:966 验证集损失：6.000157356262207
# torch.Size([379, 13])
# 当前step:967 验证集损失：5.999836444854736
# torch.Size([379, 13])
# 当前step:968 验证集损失：5.999547004699707
# torch.Size([379, 13])
# 当前step:969 验证集损失：5.9992995262146
# torch.Size([379, 13])
# 当前step:970 验证集损失：5.999018669128418
# torch.Size([379, 13])
# 当前step:971 验证集损失：5.998770713806152
# torch.Size([379, 13])
# 当前step:972 验证集损失：5.998500823974609
# torch.Size([379, 13])
# 当前step:973 验证集损失：5.998221397399902
# torch.Size([379, 13])
# 当前step:974 验证集损失：5.997928619384766
# torch.Size([379, 13])
# 当前step:975 验证集损失：5.997616767883301
# torch.Size([379, 13])
# 当前step:976 验证集损失：5.997286319732666
# torch.Size([379, 13])
# 当前step:977 验证集损失：5.996934413909912
# torch.Size([379, 13])
# 当前step:978 验证集损失：5.996528625488281
# torch.Size([379, 13])
# 当前step:979 验证集损失：5.996182441711426
# torch.Size([379, 13])
# 当前step:980 验证集损失：5.995831489562988
# torch.Size([379, 13])
# 当前step:981 验证集损失：5.995457649230957
# torch.Size([379, 13])
# 当前step:982 验证集损失：5.995155334472656
# torch.Size([379, 13])
# 当前step:983 验证集损失：5.994839668273926
# torch.Size([379, 13])
# 当前step:984 验证集损失：5.994570255279541
# torch.Size([379, 13])
# 当前step:985 验证集损失：5.994288921356201
# torch.Size([379, 13])
# 当前step:986 验证集损失：5.9939961433410645
# torch.Size([379, 13])
# 当前step:987 验证集损失：5.993736267089844
# torch.Size([379, 13])
# 当前step:988 验证集损失：5.993464946746826
# torch.Size([379, 13])
# 当前step:989 验证集损失：5.993203163146973
# torch.Size([379, 13])
# 当前step:990 验证集损失：5.9929280281066895
# torch.Size([379, 13])
# 当前step:991 验证集损失：5.992648601531982
# torch.Size([379, 13])
# 当前step:992 验证集损失：5.992353439331055
# torch.Size([379, 13])
# 当前step:993 验证集损失：5.992059707641602
# torch.Size([379, 13])
# 当前step:994 验证集损失：5.991714954376221
# torch.Size([379, 13])
# 当前step:995 验证集损失：5.99140739440918
# torch.Size([379, 13])
# 当前step:996 验证集损失：5.99106502532959
# torch.Size([379, 13])
# 当前step:997 验证集损失：5.990706920623779
# torch.Size([379, 13])
# 当前step:998 验证集损失：5.990379333496094
# torch.Size([379, 13])
# 当前step:999 验证集损失：5.99006986618042
